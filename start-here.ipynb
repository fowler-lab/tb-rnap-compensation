# %% [markdown]
# # tb-rnap-compensation

# %%
import pandas

pandas.options.display.max_columns=999

# %% [markdown]
# Let's load in the `MUTATIONS` table and have a look. Importantly, this table also records `NULL`s (where there are no reads at an amino acid so we have no evidence of what is there) and `FILTER_FAIL`s (where is some evidence but not enough to be statistically significant). These need excluding.

# %%
MUTATIONS = pandas.read_pickle('tables/MUTATIONS.pkl.gz')
MUTATIONS.reset_index(inplace=True)
MUTATIONS = MUTATIONS[(MUTATIONS.IS_FILTER_PASS) & (~MUTATIONS.IS_HET) & (~MUTATIONS.IS_NULL)]
MUTATIONS[:4]
# Out:
#                              UNIQUEID  GENE MUTATION  POSITION  \
# 0  site.02.subj.0958.lab.22A197.iso.1  rpoB     P45S      45.0
# 1  site.02.subj.0958.lab.22A197.iso.1  rpoB    S450L     450.0
# 2  site.02.subj.0958.lab.22A197.iso.1  rpoB   A1075A    1075.0
# 3  site.02.subj.0958.lab.22A197.iso.1  rpoC    D271E     271.0
#
#    AMINO_ACID_NUMBER  GENOME_INDEX  NUCLEOTIDE_NUMBER  REF  ALT  IS_SNP  \
# 0               45.0           NaN                NaN  ccg  tcg    True
# 1              450.0           NaN                NaN  tcg  ttg    True
# 2             1075.0           NaN                NaN  gct  gcc    True
# 3              271.0           NaN                NaN  gac  gag    True
#
#    IS_INDEL  IN_CDS  IN_PROMOTER  IS_SYNONYMOUS  IS_NONSYNONYMOUS  IS_HET  \
# 0     False    True        False          False              True   False
# 1     False    True        False          False              True   False
# 2     False    True        False           True             False   False
# 3     False    True        False          False              True   False
#
#    IS_NULL  IS_FILTER_PASS ELEMENT_TYPE MUTATION_TYPE  INDEL_LENGTH INDEL_1  \
# 0    False            True         GENE           AAM           NaN
# 1    False            True         GENE           AAM           NaN
# 2    False            True         GENE           AAM           NaN
# 3    False            True         GENE           AAM           NaN
#
#   INDEL_2 SITEID  NUMBER_NUCLEOTIDE_CHANGES
# 0             02                          1
# 1             02                          1
# 2             02                          1
# 3             02                          1

# %% [markdown]
# To get a quick feel for the amount of reversion that may be happening, let's do a quick cross-tab

# %%
pandas.crosstab(MUTATIONS.GENE, MUTATIONS.NUMBER_NUCLEOTIDE_CHANGES)
# Out:
# NUMBER_NUCLEOTIDE_CHANGES     0       1     2     3
# GENE
# rpoA                        219   15384   429    41
# rpoB                       9491  115155  3053   911
# rpoC                       1175  101868  3631  1108
# rpoZ                        102    1593    32     1
# sigA                        343   13279   395    79

# %% [markdown]
# Sure enough there are a good number of codons in `rpoB` and `rpoC` which have two or three bases different to the reference genome.
#
# Let's look at those were two bases are different as they fit our hypothesis (harder to explain three!)

# %%
MUTATIONS[MUTATIONS.NUMBER_NUCLEOTIDE_CHANGES == 2]
# Out:
#                                             UNIQUEID  GENE MUTATION  POSITION  \
# 817               site.02.subj.0926.lab.22A161.iso.1  rpoB    S450F     450.0
# 859               site.02.subj.0893.lab.22A127.iso.1  rpoB    D435F     435.0
# 1022          site.02.subj.0197.lab.2013221241.iso.1  sigA     A55S      55.0
# 1506              site.02.subj.0074.lab.22A026.iso.1  rpoB    H445C     445.0
# 2244      site.05.subj.LR-2335.lab.FN-01418-18.iso.1  rpoB    S450M     450.0
# ...                                              ...   ...      ...       ...
# 515444  site.10.subj.YA00134694.lab.YA00134694.iso.1  rpoB    H445G     445.0
# 516308  site.10.subj.YA00128989.lab.YA00128989.iso.1  rpoB    S441V     441.0
# 516789  site.10.subj.YA00022288.lab.YA00022288.iso.1  rpoB    H445G     445.0
# 517411  site.10.subj.LA00835602.lab.LA00835602.iso.1  rpoB    S450Q     450.0
# 517442  site.10.subj.YA00029870.lab.YA00029870.iso.1  rpoB    D435F     435.0
#
#         AMINO_ACID_NUMBER  GENOME_INDEX  NUCLEOTIDE_NUMBER  REF  ALT  IS_SNP  \
# 817                 450.0           NaN                NaN  tcg  ttc    True
# 859                 435.0           NaN                NaN  gac  ttc    True
# 1022                 55.0           NaN                NaN  gcc  tcg    True
# 1506                445.0           NaN                NaN  cac  tgc    True
# 2244                450.0           NaN                NaN  tcg  atg    True
# ...                   ...           ...                ...  ...  ...     ...
# 515444              445.0           NaN                NaN  cac  ggc    True
# 516308              441.0           NaN                NaN  tcg  gtg    True
# 516789              445.0           NaN                NaN  cac  ggc    True
# 517411              450.0           NaN                NaN  tcg  cag    True
# 517442              435.0           NaN                NaN  gac  ttc    True
#
#         IS_INDEL  IN_CDS  IN_PROMOTER  IS_SYNONYMOUS  IS_NONSYNONYMOUS  \
# 817        False    True        False          False              True
# 859        False    True        False          False              True
# 1022       False    True        False          False              True
# 1506       False    True        False          False              True
# 2244       False    True        False          False              True
# ...          ...     ...          ...            ...               ...
# 515444     False    True        False          False              True
# 516308     False    True        False          False              True
# 516789     False    True        False          False              True
# 517411     False    True        False          False              True
# 517442     False    True        False          False              True
#
#         IS_HET  IS_NULL  IS_FILTER_PASS ELEMENT_TYPE MUTATION_TYPE  \
# 817      False    False            True         GENE           AAM
# 859      False    False            True         GENE           AAM
# 1022     False    False            True         GENE           AAM
# 1506     False    False            True         GENE           AAM
# 2244     False    False            True         GENE           AAM
# ...        ...      ...             ...          ...           ...
# 515444   False    False            True         GENE           AAM
# 516308   False    False            True         GENE           AAM
# 516789   False    False            True         GENE           AAM
# 517411   False    False            True         GENE           AAM
# 517442   False    False            True         GENE           AAM
#
#         INDEL_LENGTH INDEL_1 INDEL_2 SITEID  NUMBER_NUCLEOTIDE_CHANGES
# 817              NaN                     02                          2
# 859              NaN                     02                          2
# 1022             NaN                     02                          2
# 1506             NaN                     02                          2
# 2244             NaN                     05                          2
# ...              ...     ...     ...    ...                        ...
# 515444           NaN                     10                          2
# 516308           NaN                     10                          2
# 516789           NaN                     10                          2
# 517411           NaN                     10                          2
# 517442           NaN                     10                          2
#
# [7540 rows x 25 columns]

# %%
MUTATIONS[MUTATIONS.NUMBER_NUCLEOTIDE_CHANGES == 2][:5]
# Out:
#                                         UNIQUEID  GENE MUTATION  POSITION  \
# 817           site.02.subj.0926.lab.22A161.iso.1  rpoB    S450F     450.0
# 859           site.02.subj.0893.lab.22A127.iso.1  rpoB    D435F     435.0
# 1022      site.02.subj.0197.lab.2013221241.iso.1  sigA     A55S      55.0
# 1506          site.02.subj.0074.lab.22A026.iso.1  rpoB    H445C     445.0
# 2244  site.05.subj.LR-2335.lab.FN-01418-18.iso.1  rpoB    S450M     450.0
#
#       AMINO_ACID_NUMBER  GENOME_INDEX  NUCLEOTIDE_NUMBER  REF  ALT  IS_SNP  \
# 817               450.0           NaN                NaN  tcg  ttc    True
# 859               435.0           NaN                NaN  gac  ttc    True
# 1022               55.0           NaN                NaN  gcc  tcg    True
# 1506              445.0           NaN                NaN  cac  tgc    True
# 2244              450.0           NaN                NaN  tcg  atg    True
#
#       IS_INDEL  IN_CDS  IN_PROMOTER  IS_SYNONYMOUS  IS_NONSYNONYMOUS  IS_HET  \
# 817      False    True        False          False              True   False
# 859      False    True        False          False              True   False
# 1022     False    True        False          False              True   False
# 1506     False    True        False          False              True   False
# 2244     False    True        False          False              True   False
#
#       IS_NULL  IS_FILTER_PASS ELEMENT_TYPE MUTATION_TYPE  INDEL_LENGTH  \
# 817     False            True         GENE           AAM           NaN
# 859     False            True         GENE           AAM           NaN
# 1022    False            True         GENE           AAM           NaN
# 1506    False            True         GENE           AAM           NaN
# 2244    False            True         GENE           AAM           NaN
#
#      INDEL_1 INDEL_2 SITEID  NUMBER_NUCLEOTIDE_CHANGES
# 817                      02                          2
# 859                      02                          2
# 1022                     02                          2
# 1506                     02                          2
# 2244                     05                          2

# %%
df = MUTATIONS[(MUTATIONS.GENE == 'rpoB') & (MUTATIONS.NUMBER_NUCLEOTIDE_CHANGES == 2)]
a = df.MUTATION.value_counts()
a[a>50]
# Out:
# S450F    182
# H656A    134
# E640K    134
# R662H     97
# V243T     87
# D435F     82
# A670E     73
# H445C     70
# D545K     69
# H445S     63
# L443L     59
# S641A     53
# S431S     52
# Name: MUTATION, dtype: int64

# %%
MUTATIONS[(MUTATIONS.GENE == 'rpoB') & (MUTATIONS.NUMBER_NUCLEOTIDE_CHANGES == 2) & (MUTATIONS.AMINO_ACID_NUMBER == 450)].MUTATION.value_counts()
# Out:
# S450F    182
# S450Q     15
# S450M      9
# S450V      7
# S450Y      7
# S450C      6
# S450G      5
# S450L      1
# Name: MUTATION, dtype: int64

# %%
EFFECTS = pandas.read_pickle('tables/EFFECTS.pkl.gz')
EFFECTS.reset_index(inplace=True)
EFFECTS[:5]
# Out:
#                              UNIQUEID DRUG  GENE MUTATION CATALOGUE_NAME  \
# 0  site.02.subj.0958.lab.22A197.iso.1  RFB  rpoB     P45S        CRyPTIC
# 1  site.02.subj.0958.lab.22A197.iso.1  RIF  rpoB     P45S        CRyPTIC
# 2  site.02.subj.0958.lab.22A197.iso.1  RFB  rpoB    S450L        CRyPTIC
# 3  site.02.subj.0958.lab.22A197.iso.1  RIF  rpoB    S450L        CRyPTIC
# 4  site.02.subj.0958.lab.22A197.iso.1  RFB  rpoB   A1075A        CRyPTIC
#
#   CATALOGUE_VERSION CATALOGUE_GRAMMAR SITEID PREDICTION  DEFAULT_CATALOGUE
# 0             v1.31             GARC1     02          U               True
# 1             v1.31             GARC1     02          U               True
# 2             v1.31             GARC1     02          U               True
# 3             v1.31             GARC1     02          R               True
# 4             v1.31             GARC1     02          S               True

# %%
df = EFFECTS[(EFFECTS.PREDICTION=='R') & (~EFFECTS.MUTATION.str[-1].isin(['O','X']))].MUTATION.value_counts()

# %%
df[df>5]
# Out:
# S450L         13609
# D435V          1430
# H445Y           756
# H445D           693
# D435Y           569
# L452P           549
# L430P           411
# S450W           304
# H445L           281
# I491F           232
# H445N           224
# D435G           212
# H445R           184
# S450F           182
# V170F           141
# D435F            82
# H445C            70
# H445S            63
# S441L            55
# Q432P            54
# Q432K            54
# D545E            43
# Q432L            43
# M434I            38
# L430R            33
# H445Q            32
# V359A            25
# N437D            22
# S441Q            20
# D435A            20
# 1296_indel       19
# H445G            18
# Q429L            18
# S441A            16
# Q429H            15
# S450Q            15
# A451V            14
# K446Q            14
# S431G            12
# L449M            11
# D435E            11
# M434V            10
# S428R             9
# Q432E             9
# H445P             9
# S450M             9
# 1292_indel        8
# H445T             7
# T427A             7
# S450Y             7
# S450V             7
# S450C             6
# T444I             6
# G442E             6
# R448Q             6
# S428G             6
# Name: MUTATION, dtype: int64
