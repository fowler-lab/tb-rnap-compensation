# %%
import pandas

# %%
ref = pandas.read_excel('/Users/viktoriabrunner/Documents/Studium/PhD/Project1_rev/repository/tb-rnap-compensation/Fisher_hits_analysis.xlsx', sheet_name='reference_hits')
ref
# Out:
#    resistant_mutation other_mutation   p_right_tail  p_left_tail
# 0          rpoB_H445D     rpoC_R741S   1.732629e-13          1.0
# 1          rpoB_S450L     rpoC_L507V   2.085645e-42          1.0
# 2          rpoB_S450L     rpoC_G433S   4.435243e-91          1.0
# 3          rpoB_S450L     rpoC_V483A   0.000000e+00          1.0
# 4          rpoB_S450L     rpoB_I480V   5.369895e-49          1.0
# 5          rpoB_S450L     rpoC_N698S  5.836571e-136          1.0
# 6          rpoB_S450L    rpoC_V1252L  5.800448e-114          1.0
# 7          rpoB_S450L     rpoC_L527V   2.600885e-72          1.0
# 8          rpoB_S450L     rpoA_V183G   2.380547e-41          1.0
# 9          rpoB_S450L     rpoC_W484G   2.047079e-42          1.0
# 10         rpoB_S450L     rpoC_G519D   2.158870e-20          1.0
# 11         rpoB_S450W     rpoC_G519D   1.385365e-26          1.0
# 12         rpoB_S450L     rpoC_I491T  8.808986e-294          1.0
# 13         rpoB_S450L     rpoC_D485N  1.510899e-109          1.0
# 14         rpoB_S450L     rpoC_V517L  1.350033e-123          1.0
# 15         rpoB_S450L     rpoC_D485Y  1.302924e-119          1.0
# 16         rpoB_S450L     rpoC_N698K   3.146850e-28          1.0
# 17         rpoB_S450L     rpoC_L516P   4.280525e-93          1.0
# 18         rpoB_S450L    rpoC_V1252M   1.154848e-37          1.0
# 19         rpoB_S450L     rpoC_F452S  2.659399e-231          1.0
# 20         rpoB_S450L     rpoC_V431M   2.635954e-37          1.0
# 21         rpoB_S450L     rpoC_G332R   1.128884e-69          1.0
# 22         rpoB_S450L     rpoC_T812I   3.341575e-31          1.0
# 23         rpoB_S450L    rpoC_P1040R  8.070822e-226          1.0
# 24         rpoB_S450L     rpoC_A521D   1.179542e-41          1.0
# 25         rpoB_S450L    rpoC_P1040A   1.986851e-73          1.0
# 26         rpoB_S450L     rpoC_H525Q   1.098802e-23          1.0
# 27         rpoB_S450L     rpoC_V483G   0.000000e+00          1.0
# 28         rpoB_Q432P     rpoC_V483G   2.430299e-11          1.0
# 29         rpoB_S450L     rpoC_I491V   0.000000e+00          1.0
# 30         rpoB_S450L     rpoA_T187A  2.884506e-111          1.0

# %%
print(ref.to_latex())
# Out:
# \begin{tabular}{lllrr}
# \toprule
# {} & resistant\_mutation & other\_mutation &   p\_right\_tail &  p\_left\_tail \\
# \midrule
# 0  &         rpoB\_H445D &     rpoC\_R741S &   1.732629e-13 &          1.0 \\
# 1  &         rpoB\_S450L &     rpoC\_L507V &   2.085645e-42 &          1.0 \\
# 2  &         rpoB\_S450L &     rpoC\_G433S &   4.435243e-91 &          1.0 \\
# 3  &         rpoB\_S450L &     rpoC\_V483A &   0.000000e+00 &          1.0 \\
# 4  &         rpoB\_S450L &     rpoB\_I480V &   5.369895e-49 &          1.0 \\
# 5  &         rpoB\_S450L &     rpoC\_N698S &  5.836571e-136 &          1.0 \\
# 6  &         rpoB\_S450L &    rpoC\_V1252L &  5.800448e-114 &          1.0 \\
# 7  &         rpoB\_S450L &     rpoC\_L527V &   2.600885e-72 &          1.0 \\
# 8  &         rpoB\_S450L &     rpoA\_V183G &   2.380547e-41 &          1.0 \\
# 9  &         rpoB\_S450L &     rpoC\_W484G &   2.047079e-42 &          1.0 \\
# 10 &         rpoB\_S450L &     rpoC\_G519D &   2.158870e-20 &          1.0 \\
# 11 &         rpoB\_S450W &     rpoC\_G519D &   1.385365e-26 &          1.0 \\
# 12 &         rpoB\_S450L &     rpoC\_I491T &  8.808986e-294 &          1.0 \\
# 13 &         rpoB\_S450L &     rpoC\_D485N &  1.510899e-109 &          1.0 \\
# 14 &         rpoB\_S450L &     rpoC\_V517L &  1.350033e-123 &          1.0 \\
# 15 &         rpoB\_S450L &     rpoC\_D485Y &  1.302924e-119 &          1.0 \\
# 16 &         rpoB\_S450L &     rpoC\_N698K &   3.146850e-28 &          1.0 \\
# 17 &         rpoB\_S450L &     rpoC\_L516P &   4.280525e-93 &          1.0 \\
# 18 &         rpoB\_S450L &    rpoC\_V1252M &   1.154848e-37 &          1.0 \\
# 19 &         rpoB\_S450L &     rpoC\_F452S &  2.659399e-231 &          1.0 \\
# 20 &         rpoB\_S450L &     rpoC\_V431M &   2.635954e-37 &          1.0 \\
# 21 &         rpoB\_S450L &     rpoC\_G332R &   1.128884e-69 &          1.0 \\
# 22 &         rpoB\_S450L &     rpoC\_T812I &   3.341575e-31 &          1.0 \\
# 23 &         rpoB\_S450L &    rpoC\_P1040R &  8.070822e-226 &          1.0 \\
# 24 &         rpoB\_S450L &     rpoC\_A521D &   1.179542e-41 &          1.0 \\
# 25 &         rpoB\_S450L &    rpoC\_P1040A &   1.986851e-73 &          1.0 \\
# 26 &         rpoB\_S450L &     rpoC\_H525Q &   1.098802e-23 &          1.0 \\
# 27 &         rpoB\_S450L &     rpoC\_V483G &   0.000000e+00 &          1.0 \\
# 28 &         rpoB\_Q432P &     rpoC\_V483G &   2.430299e-11 &          1.0 \\
# 29 &         rpoB\_S450L &     rpoC\_I491V &   0.000000e+00 &          1.0 \\
# 30 &         rpoB\_S450L &     rpoA\_T187A &  2.884506e-111 &          1.0 \\
# \bottomrule
# \end{tabular}

# %%
new = pandas.read_excel('/Users/viktoriabrunner/Documents/Studium/PhD/Project1_rev/repository/tb-rnap-compensation/Fisher_hits_analysis.xlsx', sheet_name='new_hits')
new
# Out:
#    resistant_mutation other_mutation   p_right_tail  p_left_tail
# 0          rpoB_S450L    rpoC_K1152Q   2.687247e-35          1.0
# 1          rpoB_S450L    rpoC_P1040S   1.174498e-75          1.0
# 2          rpoB_D435Y     rpoB_c-61t   3.003363e-22          1.0
# 3          rpoB_H445Y     rpoC_S548S   3.434460e-74          1.0
# 4          rpoB_S450L      rpoB_P45L   1.415590e-20          1.0
# 5          rpoB_S450W      rpoB_P45L   7.350381e-14          1.0
# 6          rpoB_S450L    rpoC_E1092D   0.000000e+00          1.0
# 7          rpoB_L430P    rpoC_E1092D   1.497314e-20          1.0
# 8          rpoB_S450L     rpoB_V496A   2.097831e-41          1.0
# 9          rpoB_S450L     rpoC_K445R   3.248977e-67          1.0
# 10         rpoB_S450L     rpoB_L731P  3.609345e-152          1.0
# 11         rpoB_S450L     rpoC_N416S   5.049842e-45          1.0
# 12         rpoB_H445N      rpoC_Y61Y   1.492739e-19          1.0
# 13         rpoB_I491F     rpoC_G594E   6.863893e-22          1.0
# 14         rpoB_D435V     rpoC_P481T   1.355628e-13          1.0
# 15         rpoB_S450L    rpoC_V1039A   4.261623e-45          1.0
# 16         rpoB_D435G    rpoB_I1106T  1.976028e-264          1.0
# 17         rpoB_L452P    rpoB_I1106T  3.221075e-213          1.0
# 18         rpoB_S450L     rpoC_G332S  6.415276e-101          1.0
# 19         rpoB_S450L     rpoB_I488V   1.154848e-37          1.0
# 20         rpoB_S450L     rpoB_Q409R   1.694883e-33          1.0
# 21         rpoB_S450L    rpoB_A1075A   8.033765e-77          1.0
# 22         rpoB_L430P    rpoB_A1075A   2.935139e-16          1.0
# 23         rpoB_S450L      rpoC_C62C  4.090812e-134          1.0
# 24         rpoB_S450L      rpoZ_S22S   4.261623e-45          1.0
# 25         rpoB_S450L      rpoB_P45S   3.228730e-38          1.0
# 26         rpoB_S450L     rpoB_K891E   6.562622e-51          1.0
# 27         rpoB_D435G     rpoC_A542A   1.214582e-30          1.0
# 28         rpoB_H445D     rpoC_A542A   4.611790e-31          1.0
# 29         rpoB_D435V     rpoC_A542A   5.241114e-48          1.0
# 30         rpoB_L452P     rpoC_A542A   1.144542e-19          1.0
# 31         rpoB_S450L     rpoC_F452L   5.814167e-61          1.0
# 32         rpoB_S450L     rpoC_L547V   1.154129e-51          1.0
# 33         rpoB_S450L     rpoB_Q975H   2.705866e-29          1.0
# 34         rpoB_S450L     rpoB_A286V   2.109150e-33          1.0
# 35         rpoB_S450L     rpoB_R827C   8.775875e-73          1.0
# 36         rpoB_S450L     rpoB_A692T   3.586383e-38          1.0
# 37         rpoB_I491F    rpoC_E1033A   2.515390e-96          1.0
# 38         rpoB_D435Y     rpoB_G876G   1.136266e-20          1.0
# 39         rpoB_S450W     sigA_D146E   1.912331e-25          1.0
# 40         rpoB_S450L     rpoC_N826T   4.042508e-44          1.0
# 41         rpoB_S450L     rpoB_E761D  8.955862e-208          1.0
# 42         rpoB_S450W     rpoC_L873L   2.741837e-21          1.0

# %%
print(new.to_latex())
# Out:
# \begin{tabular}{lllrr}
# \toprule
# {} & resistant\_mutation & other\_mutation &   p\_right\_tail &  p\_left\_tail \\
# \midrule
# 0  &         rpoB\_S450L &    rpoC\_K1152Q &   2.687247e-35 &          1.0 \\
# 1  &         rpoB\_S450L &    rpoC\_P1040S &   1.174498e-75 &          1.0 \\
# 2  &         rpoB\_D435Y &     rpoB\_c-61t &   3.003363e-22 &          1.0 \\
# 3  &         rpoB\_H445Y &     rpoC\_S548S &   3.434460e-74 &          1.0 \\
# 4  &         rpoB\_S450L &      rpoB\_P45L &   1.415590e-20 &          1.0 \\
# 5  &         rpoB\_S450W &      rpoB\_P45L &   7.350381e-14 &          1.0 \\
# 6  &         rpoB\_S450L &    rpoC\_E1092D &   0.000000e+00 &          1.0 \\
# 7  &         rpoB\_L430P &    rpoC\_E1092D &   1.497314e-20 &          1.0 \\
# 8  &         rpoB\_S450L &     rpoB\_V496A &   2.097831e-41 &          1.0 \\
# 9  &         rpoB\_S450L &     rpoC\_K445R &   3.248977e-67 &          1.0 \\
# 10 &         rpoB\_S450L &     rpoB\_L731P &  3.609345e-152 &          1.0 \\
# 11 &         rpoB\_S450L &     rpoC\_N416S &   5.049842e-45 &          1.0 \\
# 12 &         rpoB\_H445N &      rpoC\_Y61Y &   1.492739e-19 &          1.0 \\
# 13 &         rpoB\_I491F &     rpoC\_G594E &   6.863893e-22 &          1.0 \\
# 14 &         rpoB\_D435V &     rpoC\_P481T &   1.355628e-13 &          1.0 \\
# 15 &         rpoB\_S450L &    rpoC\_V1039A &   4.261623e-45 &          1.0 \\
# 16 &         rpoB\_D435G &    rpoB\_I1106T &  1.976028e-264 &          1.0 \\
# 17 &         rpoB\_L452P &    rpoB\_I1106T &  3.221075e-213 &          1.0 \\
# 18 &         rpoB\_S450L &     rpoC\_G332S &  6.415276e-101 &          1.0 \\
# 19 &         rpoB\_S450L &     rpoB\_I488V &   1.154848e-37 &          1.0 \\
# 20 &         rpoB\_S450L &     rpoB\_Q409R &   1.694883e-33 &          1.0 \\
# 21 &         rpoB\_S450L &    rpoB\_A1075A &   8.033765e-77 &          1.0 \\
# 22 &         rpoB\_L430P &    rpoB\_A1075A &   2.935139e-16 &          1.0 \\
# 23 &         rpoB\_S450L &      rpoC\_C62C &  4.090812e-134 &          1.0 \\
# 24 &         rpoB\_S450L &      rpoZ\_S22S &   4.261623e-45 &          1.0 \\
# 25 &         rpoB\_S450L &      rpoB\_P45S &   3.228730e-38 &          1.0 \\
# 26 &         rpoB\_S450L &     rpoB\_K891E &   6.562622e-51 &          1.0 \\
# 27 &         rpoB\_D435G &     rpoC\_A542A &   1.214582e-30 &          1.0 \\
# 28 &         rpoB\_H445D &     rpoC\_A542A &   4.611790e-31 &          1.0 \\
# 29 &         rpoB\_D435V &     rpoC\_A542A &   5.241114e-48 &          1.0 \\
# 30 &         rpoB\_L452P &     rpoC\_A542A &   1.144542e-19 &          1.0 \\
# 31 &         rpoB\_S450L &     rpoC\_F452L &   5.814167e-61 &          1.0 \\
# 32 &         rpoB\_S450L &     rpoC\_L547V &   1.154129e-51 &          1.0 \\
# 33 &         rpoB\_S450L &     rpoB\_Q975H &   2.705866e-29 &          1.0 \\
# 34 &         rpoB\_S450L &     rpoB\_A286V &   2.109150e-33 &          1.0 \\
# 35 &         rpoB\_S450L &     rpoB\_R827C &   8.775875e-73 &          1.0 \\
# 36 &         rpoB\_S450L &     rpoB\_A692T &   3.586383e-38 &          1.0 \\
# 37 &         rpoB\_I491F &    rpoC\_E1033A &   2.515390e-96 &          1.0 \\
# 38 &         rpoB\_D435Y &     rpoB\_G876G &   1.136266e-20 &          1.0 \\
# 39 &         rpoB\_S450W &     sigA\_D146E &   1.912331e-25 &          1.0 \\
# 40 &         rpoB\_S450L &     rpoC\_N826T &   4.042508e-44 &          1.0 \\
# 41 &         rpoB\_S450L &     rpoB\_E761D &  8.955862e-208 &          1.0 \\
# 42 &         rpoB\_S450W &     rpoC\_L873L &   2.741837e-21 &          1.0 \\
# \bottomrule
# \end{tabular}
